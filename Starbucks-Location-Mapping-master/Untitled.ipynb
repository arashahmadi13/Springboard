# %%
import pandas as pd
df1 = pd.read_csv('acs2015_county_data.csv')

# %%
df1.tai
# Out:
#       CensusId        State     County  TotalPop    Men  Women  Hispanic  \
# 3215     72145  Puerto Rico  Vega Baja     56858  27379  29479      96.4
# 3216     72147  Puerto Rico    Vieques      9130   4585   4545      96.7
# 3217     72149  Puerto Rico   Villalba     24685  12086  12599      99.7
# 3218     72151  Puerto Rico    Yabucoa     36279  17648  18631      99.8
# 3219     72153  Puerto Rico      Yauco     39474  19047  20427      99.5
#
#       White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 3215    3.4    0.1     0.0  ...   1.2          1.3         0.3         32.0
# 3216    2.9    0.0     0.0  ...  10.8          0.0         1.4         14.0
# 3217    0.0    0.0     0.0  ...   3.2          0.0         3.3         26.9
# 3218    0.2    0.0     0.0  ...   2.3          2.3         1.5         29.5
# 3219    0.5    0.0     0.0  ...   1.6          0.7         3.1         24.6
#
#       Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# ...

# %%
df2 = pd.read_csv('store_data.csv')
df2.Postcode.unique()
# Out:
# array(['AD500', nan, '3167', ..., '2194', '181', '1682'], dtype=object)

# %%
df2 = df2[df2.Country == 'US']
df2.head(100)
# Out:
#            Brand  Store Number                       Store Name  \
# 11964  Starbucks   3513-125945          Safeway-Anchorage #1809
# 11965  Starbucks   74352-84449          Safeway-Anchorage #2628
# 11966  Starbucks  12449-152385        Safeway - Anchorage #1813
# 11967  Starbucks  24936-233524         100th & C St - Anchorage
# 11968  Starbucks    8973-85630             Old Seward & Diamond
# ...          ...           ...                              ...
# 12059  Starbucks  12493-152666         Kroger - Huntsville #677
# 12060  Starbucks   72635-32262  Super Target Huntsville ST-1346
# 12061  Starbucks   10062-99521           Memorial Pkwy & Hwy 72
# 12062  Starbucks  11428-104120                  Hwy 72 & Hughes
# 12063  Starbucks  48885-260445               Kroger Madison 605
#
#       Ownership Type                                     Street Address  \
# 11964       Licensed                               5600 Debarr Rd Ste 9
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CensusId         3220 non-null   int64
#  1   State            3220 non-null   object
#  2   County           3220 non-null   object
#  3   TotalPop         3220 non-null   int64
#  4   Men              3220 non-null   int64
#  5   Women            3220 non-null   int64
#  6   Hispanic         3220 non-null   float64
#  7   White            3220 non-null   float64
#  8   Black            3220 non-null   float64
#  9   Native           3220 non-null   float64
#  10  Asian            3220 non-null   float64
#  11  Pacific          3220 non-null   float64
#  12  Citizen          3220 non-null   int64
#  13  Income           3219 non-null   float64
#  14  IncomeErr        3219 non-null   float64
#  15  IncomePerCap     3220 non-null   int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13608 entries, 11964 to 25571
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           13608 non-null  object
#  1   Store Number    13608 non-null  object
#  2   Store Name      13608 non-null  object
#  3   Ownership Type  13608 non-null  object
#  4   Street Address  13608 non-null  object
#  5   City            13608 non-null  object
#  6   State/Province  13608 non-null  object
#  7   Country         13608 non-null  object
#  8   Postcode        13607 non-null  object
#  9   Phone Number    13122 non-null  object
#  10  Timezone        13608 non-null  object
#  11  Longitude       13608 non-null  float64
#  12  Latitude        13608 non-null  float64
# dtypes: float64(2), object(11)
# memory usage: 1.5+ MB

# %%
df2.groupby('City').head()
# Out:
#            Brand  Store Number                        Store Name  \
# 11964  Starbucks   3513-125945           Safeway-Anchorage #1809
# 11965  Starbucks   74352-84449           Safeway-Anchorage #2628
# 11966  Starbucks  12449-152385         Safeway - Anchorage #1813
# 11967  Starbucks  24936-233524          100th & C St - Anchorage
# 11968  Starbucks    8973-85630              Old Seward & Diamond
# ...          ...           ...                               ...
# 25567  Starbucks   74385-87621             Safeway-Laramie #2466
# 25568  Starbucks   73320-24375          Ridley's - Laramie #1131
# 25569  Starbucks  22425-219024            Laramie - Grand & 30th
# 25570  Starbucks  10849-103163      I-80 & Dewar Dr-Rock Springs
# 25571  Starbucks  10769-102454  Coffeen & Brundage Lane-Sheridan
#
#       Ownership Type                                     Street Address  \
# 11964       Licensed                               5600 Debarr Rd Ste 9
# ...

# %%
df2.tail()
# Out:
#            Brand  Store Number                        Store Name  \
# 25567  Starbucks   74385-87621             Safeway-Laramie #2466
# 25568  Starbucks   73320-24375          Ridley's - Laramie #1131
# 25569  Starbucks  22425-219024            Laramie - Grand & 30th
# 25570  Starbucks  10849-103163      I-80 & Dewar Dr-Rock Springs
# 25571  Starbucks  10769-102454  Coffeen & Brundage Lane-Sheridan
#
#       Ownership Type    Street Address          City State/Province Country  \
# 25567       Licensed      554 N 3rd St       Laramie             WY      US
# 25568       Licensed     3112 E. Grand       Laramie             WY      US
# 25569  Company Owned    3021 Grand Ave       Laramie             WY      US
# 25570  Company Owned  118 Westland Way  Rock Springs             WY      US
# 25571  Company Owned  2208 Coffeen Ave     Sheridian             WY      US
#
#         Postcode  Phone Number                  Timezone  Longitude  Latitude
# ...
