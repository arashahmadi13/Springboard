# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\arash\Desktop\SpringBoard\Starbucks-Location-Mapping-master\Starbucks-Location-Mapping-master\store_data.csv")
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
df.dtypes
# Out:
# Brand              object
# Store Number       object
# Store Name         object
# Ownership Type     object
# Street Address     object
# City               object
# State/Province     object
# Country            object
# Postcode           object
# Phone Number       object
# Timezone           object
# Longitude         float64
# Latitude          float64
# dtype: object

# %%
df.select_dtypes(exclude=['int', 'float'])
# Out:
#            Brand  Store Number        Store Name Ownership Type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# ...

# %%
df['Ownership Type'].value_counts()
# Out:
# Company Owned    11932
# Licensed          9375
# Joint Venture     3976
# Franchise          317
# Name: Ownership Type, dtype: int64

# %%
df = pd.get_dummies(df, columns=['Ownership Type'], drop_first=True)

# %%
df
# Out:
#            Brand  Store Number        Store Name  \
# 0      Starbucks  47370-257954     Meritxell, 96
# 1      Starbucks  22331-212325  Ajman Drive Thru
# 2      Starbucks  47089-256771         Dana Mall
# 3      Starbucks  22126-218024        Twofour 54
# 4      Starbucks  17127-178586      Al Ain Tower
# ...          ...           ...               ...
# 25595  Starbucks  21401-212072               Rex
# 25596  Starbucks  24010-226985          Panorama
# 25597  Starbucks  47608-253804     Rosebank Mall
# 25598  Starbucks  47640-253809      Menlyn Maine
# 25599  Starbucks  47609-253286    Mall of Africa
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# 2                           Sheikh Khalifa Bin Zayed St.
# 3                                        Al Salam Street
# 4                        Khaldiya Area, Abu Dhabi Island
# ...

# %%
df['State/Province'][df['State/Province'].value_counts()<500]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-46-2bc23f6f1d6a> in <module>
# ----> 1 df['State/Province'][df['State/Province'].value_counts()<500]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     871
#     872         if com.is_bool_indexer(key):
# --> 873             key = check_bool_indexer(self.index, key)
#     874             key = np.asarray(key, dtype=bool)
#     875             return self._get_values(key)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2267         mask = isna(result._values)
#    2268         if mask.any():
# -> 2269             raise IndexingError(
#    2270                 "Unalignable boolean Series provided as "
#    2271                 "indexer (index of the boolean Series and of "
#
# ...

# %%
df['State/Province'].nunique()
# Out:
# 337

# %%
df[list(df['State/Province'].value_counts()<500)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-db21fc3a060c> in <module>
# ----> 1 df[list(df['State/Province'].value_counts()<500)]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3060             )
#    3061         elif len(key) != len(self.index):
# -> 3062             raise ValueError(
#    3063                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3064             )
#
# ValueError: Item wrong length 337 instead of 25600.

# %%
counts = df['State/Province'].value_counts()

# %%
type(df['State/Province'].value_counts()>500)
# Out:
# pandas.core.series.Series

# %%
df['State/Province'][(df['State/Province'].value_counts())[df['State/Province'].value_counts()<500]] = 'other'
# Out:
# <ipython-input-63-60953abe8e0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['State/Province'][(df['State/Province'].value_counts())[df['State/Province'].value_counts()<500]] = 'other'

# %%
df['State/Province'].nunique()
# Out:
# 337

# %%
m = (df['State/Province'].value_counts())[df['State/Province'].value_counts()<500]

# %%
df['State/Province'][m] = 'other'
# Out:
# <ipython-input-71-7613125c6e6c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['State/Province'][m] = 'other'

# %%
df['State/Province'][m].nunique()
# Out:
# 1

# %%
(df['State/Province'].value_counts()<500).nunique()
# Out:
# 2

# %%
m = df['State/Province'].isin(counts[counts<500].index)

# %%
df['State/Province'][m] = 'other'
# Out:
# <ipython-input-93-7613125c6e6c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['State/Province'][m] = 'other'

# %%
df['State/Province'].nunique()
# Out:
# 12

# %%
df['Area'] = pd.cut(df['Longitude'], 
                   bins= [-np.inf, 40, 80, np.inf],
                   labels=['west', 'middle', 'east'])

# %%
df
# Out:
#            Brand  Store Number        Store Name  \
# 0      Starbucks  47370-257954     Meritxell, 96
# 1      Starbucks  22331-212325  Ajman Drive Thru
# 2      Starbucks  47089-256771         Dana Mall
# 3      Starbucks  22126-218024        Twofour 54
# 4      Starbucks  17127-178586      Al Ain Tower
# ...          ...           ...               ...
# 25595  Starbucks  21401-212072               Rex
# 25596  Starbucks  24010-226985          Panorama
# 25597  Starbucks  47608-253804     Rosebank Mall
# 25598  Starbucks  47640-253809      Menlyn Maine
# 25599  Starbucks  47609-253286    Mall of Africa
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# 2                           Sheikh Khalifa Bin Zayed St.
# 3                                        Al Salam Street
# 4                        Khaldiya Area, Abu Dhabi Island
# ...
